# %%
import sys
import MapReduce as mapreduce
import csv
import pandas as pd
from collections import defaultdict
import statsmodels.formula.api as sm


# Open the file and sets up the dictionaries
def mapper(record):
    csvr=csv.DictReader(record, delimiter=',')
    rlist=defaultdict(list)
    i=0
    cols=[]
#     while i<10:
    for c in csvr:
        for cc in c:
            rlist[cc].append(c[cc])
            if cc=='datetime':
                hour=c[cc][-5:-3].strip()
                
                rlist['time'].append(hour)
            
#                 cols.append(cc)
#             i+=1
#     print rlist['time']
    cols=rlist.keys()
    df=pd.DataFrame(rlist, columns=cols)
    df[['temp','atemp','windspeed','humidity', 'casual','registered', 'count']]=df[['temp','atemp','windspeed','humidity', 'casual','registered', 'count']].astype(float)
    df[['holiday','season','workingday','weather','time']]=df[['holiday','season','workingday','weather','time']].astype(int)
    df['datetime']=df['datetime'].astype(str)
    
    
#     deleting when season equals 3
#     df=df[df.season !=3]
#     df=df[df.season !=2]
    return df




def reducer(df):
#     print df.describe()
#     form="count~C(holiday)+C(workingday)+C(weather)+temp+atemp+humidity+windspeed+C(time)"
    form="count~C(time)+atemp+C(season)+humidity+windspeed"
#     form="count~time+C(holiday)+windspeed+C(workingday)+atemp"
    
    result=sm.ols(formula=form,data=df).fit()
#     print result.params
#     print result.predict()

#     how to tell this is off
    df['pred']=result.predict()
    off=[]
    for i,v in zip(df['count'],df['pred']):
        off.append(abs(i-v))
    df['off']=off
#         print i,v

    print df['off']
    print df.describe()
    print result.summary()
#     print results.intercept
#     df[pred]=result.params[1]+result.params[2]+result.params[0]
    
        

trainfile =open(r"C:\Users\Dex\Documents\IPython Notebooks\cert\kaggle\train.csv", "r")
# testfile = open('C:\Users\Dex\Documents\IPython Notebooks\cert\kaggle\train.csv', 'rb')
df=mapper(trainfile)
reducer(df)
# Out:
# 0      51.703668
# 1      95.471384
# 2      96.549293
# 3      75.395928
# 4      63.443413
# 5      61.245685
# 6       1.352589
# 7     117.788352
# 8     279.286088
# 9     138.105342
# 10     57.298412
# 11     34.590304
# 12     75.477956
# 13     74.014613
# 14     43.848492
# ...
# 10871    118.414403
# 10872      3.230429
# 10873     22.736379
# 10874     20.193691
# 10875     51.601331
# 10876     27.619679
# 10877     13.555924
# 10878     23.414317
# 10879     99.482874
# 10880    141.409557
# 10881     16.869796
# 10882     16.318856
# 10883      6.271434
# 10884     14.869156
# 10885      2.813745
# Name: off, Length: 10886, dtype: float64
#               count       holiday         temp        season    registered  \
# count  10886.000000  10886.000000  10886.00000  10886.000000  10886.000000
# mean     191.574132      0.028569     20.23086      2.506614    155.552177
# std      181.144454      0.166599      7.79159      1.116174    151.039033
# min        1.000000      0.000000      0.82000      1.000000      0.000000
# 25%       42.000000      0.000000     13.94000      2.000000     36.000000
# 50%      145.000000      0.000000     20.50000      3.000000    118.000000
# 75%      284.000000      0.000000     26.24000      4.000000    222.000000
# max      977.000000      1.000000     41.00000      4.000000    886.000000
#
#               atemp    workingday     windspeed       weather          time  \
# count  10886.000000  10886.000000  10886.000000  10886.000000  10886.000000
# mean      23.655